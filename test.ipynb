# %%
import json
import os

# %%
print(os.getcwd())
# Out:
# /Users/takuyakinoshita/python/algo-trading

# %%
from app.models.dfcandle import DataframeCandle
from app.models.conductor import Conductor

# %%
cond = Conductor()
print(f'duration: {cond.duration}')
cond.get_data(5)
print(cond.data.to_string())
# Out:
# duration: 5m
#                          open      high       low    close  volume    return  \
# time
# 2024-03-30 05:50:00  151.3745  151.3765  151.3365  151.363       0 -0.000076
# 2024-03-30 05:55:00  151.3630  151.3675  151.3405  151.348       0 -0.000099
# 2024-03-30 06:00:00  151.3480  151.3480  151.3480  151.348       0  0.000000
# 2024-03-30 06:05:00  151.3480  151.3480  151.3480  151.348       0  0.000000
# 2024-03-30 06:10:00  151.3480  151.3480  151.3480  151.348       0  0.000000
#
#                      momentum
# time
# 2024-03-30 05:50:00  0.000023
# 2024-03-30 05:55:00 -0.000003
# 2024-03-30 06:00:00 -0.000006
# 2024-03-30 06:05:00 -0.000005
# 2024-03-30 06:10:00 -0.000035
# -3.501556715168649e-05

# %%
cond.plot_chart()
# Out:
# /Users/takuyakinoshita/python/algo-trading/.venv/lib/python3.12/site-packages/mplfinance/plotting.py:707: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   volumeAxes.set_ylim(vymin,vymax)

# %%
dict = {'status': 0, 'data': {'list': []}, 'responsetime': '2024-03-27T23:31:28.843Z'}
js = json.dumps(dict)
print(js)
print(type(js))
js = json.loads(js)
print(js)
print(type(js))
print(js["data"]["list"])
# Out:
# {"status": 0, "data": {"list": []}, "responsetime": "2024-03-27T23:31:28.843Z"}
# <class 'str'>
# {'status': 0, 'data': {'list': []}, 'responsetime': '2024-03-27T23:31:28.843Z'}
# <class 'dict'>
# []
