# %%
import json
import os

# %%
print(os.getcwd())
# Out:
# /Users/takuyakinoshita/python/algo-trading

# %%
from app.models.dfcandle import DataframeCandle
from app.models.conductor import Conductor

# %%
cond = Conductor()
cond.get_data(5)
print(cond.data.tail())
print(cond.data["momentum"].iloc[-1])
# Out:
# Empty DataFrame
# Columns: [open, high, low, close, volume, return, momentum]
# Index: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 cond.get_data(10)
#       3 print(cond.data.tail())
# ----> 4 print(cond.data["momentum"].iloc[-1])
#
# File ~/python/algo-trading/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/python/algo-trading/.venv/lib/python3.12/site-packages/pandas/core/indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# ...

# %%
cond.plot_chart()
# Out:
# /Users/takuyakinoshita/python/algo-trading/.venv/lib/python3.12/site-packages/mplfinance/plotting.py:707: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   volumeAxes.set_ylim(vymin,vymax)

# %%
dict = {'status': 0, 'data': {'list': []}, 'responsetime': '2024-03-27T23:31:28.843Z'}
js = json.dumps(dict)
print(js)
print(type(js))
js = json.loads(js)
print(js)
print(type(js))
print(js["data"]["list"])
# Out:
# {"status": 0, "data": {"list": []}, "responsetime": "2024-03-27T23:31:28.843Z"}
# <class 'str'>
# {'status': 0, 'data': {'list': []}, 'responsetime': '2024-03-27T23:31:28.843Z'}
# <class 'dict'>
# []
